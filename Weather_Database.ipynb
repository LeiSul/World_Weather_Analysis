# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 747

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": city_description,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | omboue
# Processing Record 2 of Set 1 | zhigansk
# Processing Record 3 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 1 | hodmezovasarhely
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | bonfim
# Processing Record 8 of Set 1 | puerto ayora
# Processing Record 9 of Set 1 | marsh harbour
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | quatre cocos
# Processing Record 12 of Set 1 | bluff
# Processing Record 13 of Set 1 | lorengau
# Processing Record 14 of Set 1 | sao filipe
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 1 | hobart
# Processing Record 18 of Set 1 | baker city
# Processing Record 19 of Set 1 | saskylakh
# Processing Record 20 of Set 1 | cape town
# Processing Record 21 of Set 1 | nikolskoye
# Processing Record 22 of Set 1 | hithadhoo
# Processing Record 23 of Set 1 | atuona
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | kodiak
# Processing Record 26 of Set 1 | tila
# Processing Record 27 of Set 1 | veraval
# Processing Record 28 of Set 1 | ribeira grande
# Processing Record 29 of Set 1 | sobolevo
# Processing Record 30 of Set 1 | tuktoyaktuk
# Processing Record 31 of Set 1 | tiksi
# Processing Record 32 of Set 1 | whitehorse
# Processing Record 33 of Set 1 | labytnangi
# Processing Record 34 of Set 1 | sitka
# Processing Record 35 of Set 1 | sistranda
# Processing Record 36 of Set 1 | mount gambier
# Processing Record 37 of Set 1 | pemba
# Processing Record 38 of Set 1 | saint-philippe
# Processing Record 39 of Set 1 | bredasdorp
# Processing Record 40 of Set 1 | samarai
# Processing Record 41 of Set 1 | new norfolk
# Processing Record 42 of Set 1 | ancud
# Processing Record 43 of Set 1 | hlotse
# Processing Record 44 of Set 1 | bulawayo
# Processing Record 45 of Set 1 | florianopolis
# Processing Record 46 of Set 1 | sao paulo de olivenca
# Processing Record 47 of Set 1 | hilo
# Processing Record 48 of Set 1 | ushuaia
# Processing Record 49 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 50 of Set 1 | pevek
# Processing Record 1 of Set 2 | kapaa
# Processing Record 2 of Set 2 | port blair
# Processing Record 3 of Set 2 | kalmunai
# Processing Record 4 of Set 2 | pisco
# Processing Record 5 of Set 2 | mirabad
# Processing Record 6 of Set 2 | balkanabat
# Processing Record 7 of Set 2 | parrsboro
# Processing Record 8 of Set 2 | cidreira
# Processing Record 9 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 2 | san cristobal
# Processing Record 11 of Set 2 | mar del plata
# Processing Record 12 of Set 2 | dingle
# Processing Record 13 of Set 2 | yellowknife
# Processing Record 14 of Set 2 | barrow
# Processing Record 15 of Set 2 | salina
# Processing Record 16 of Set 2 | savannah bight
# Processing Record 17 of Set 2 | abadan
# Processing Record 18 of Set 2 | loandjili
# Processing Record 19 of Set 2 | longlac
# City not found. Skipping...
# Processing Record 20 of Set 2 | kaitangata
# Processing Record 21 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 2 | boende
# Processing Record 23 of Set 2 | slave lake
# Processing Record 24 of Set 2 | port alfred
# Processing Record 25 of Set 2 | barra bonita
# Processing Record 26 of Set 2 | vaini
# Processing Record 27 of Set 2 | thompson
# Processing Record 28 of Set 2 | sumbe
# Processing Record 29 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 2 | sohag
# Processing Record 31 of Set 2 | grindavik
# Processing Record 32 of Set 2 | san quintin
# Processing Record 33 of Set 2 | thinadhoo
# Processing Record 34 of Set 2 | sarangani
# Processing Record 35 of Set 2 | asyut
# Processing Record 36 of Set 2 | bengkulu
# Processing Record 37 of Set 2 | mahebourg
# Processing Record 38 of Set 2 | dikson
# Processing Record 39 of Set 2 | port lincoln
# Processing Record 40 of Set 2 | yeppoon
# Processing Record 41 of Set 2 | qaanaaq
# Processing Record 42 of Set 2 | clyde river
# Processing Record 43 of Set 2 | jamestown
# Processing Record 44 of Set 2 | nizwa
# Processing Record 45 of Set 2 | ilulissat
# Processing Record 46 of Set 2 | serafimovich
# Processing Record 47 of Set 2 | chuy
# Processing Record 48 of Set 2 | santa cruz de la palma
# Processing Record 49 of Set 2 | isangel
# Processing Record 50 of Set 2 | hermanus
# Processing Record 1 of Set 3 | kruisfontein
# Processing Record 2 of Set 3 | lynchburg
# Processing Record 3 of Set 3 | seoul
# Processing Record 4 of Set 3 | bayeux
# Processing Record 5 of Set 3 | doha
# Processing Record 6 of Set 3 | vila do maio
# Processing Record 7 of Set 3 | khani
# Processing Record 8 of Set 3 | jardim
# Processing Record 9 of Set 3 | east london
# Processing Record 10 of Set 3 | lebu
# Processing Record 11 of Set 3 | chokurdakh
# Processing Record 12 of Set 3 | provideniya
# Processing Record 13 of Set 3 | rio gallegos
# Processing Record 14 of Set 3 | la cruz
# Processing Record 15 of Set 3 | jahrom
# City not found. Skipping...
# Processing Record 16 of Set 3 | saint george
# Processing Record 17 of Set 3 | qaqortoq
# Processing Record 18 of Set 3 | nago
# Processing Record 19 of Set 3 | cheremukhovo
# Processing Record 20 of Set 3 | vostok
# Processing Record 21 of Set 3 | bambous virieux
# Processing Record 22 of Set 3 | norman wells
# Processing Record 23 of Set 3 | belmonte
# Processing Record 24 of Set 3 | tasiilaq
# Processing Record 25 of Set 3 | dzaoudzi
# Processing Record 26 of Set 3 | mineral wells
# Processing Record 27 of Set 3 | makakilo city
# Processing Record 28 of Set 3 | castro
# Processing Record 29 of Set 3 | aklavik
# Processing Record 30 of Set 3 | sept-iles
# Processing Record 31 of Set 3 | aksarka
# Processing Record 32 of Set 3 | dunedin
# Processing Record 33 of Set 3 | chegdomyn
# Processing Record 34 of Set 3 | sioux lookout
# Processing Record 35 of Set 3 | urumqi
# Processing Record 36 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 38 of Set 3 | atar
# Processing Record 39 of Set 3 | langsa
# Processing Record 40 of Set 3 | santa elena
# Processing Record 41 of Set 3 | rach gia
# Processing Record 42 of Set 3 | saint-pierre
# Processing Record 43 of Set 3 | pacific grove
# Processing Record 44 of Set 3 | shahganj
# Processing Record 45 of Set 3 | torbay
# Processing Record 46 of Set 3 | cam ranh
# Processing Record 47 of Set 3 | alyangula
# Processing Record 48 of Set 3 | adrar
# Processing Record 49 of Set 3 | coquimbo
# Processing Record 50 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 1 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 4 | oranjemund
# Processing Record 3 of Set 4 | asau
# Processing Record 4 of Set 4 | zhanaozen
# Processing Record 5 of Set 4 | avarua
# Processing Record 6 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 7 of Set 4 | guerrero negro
# Processing Record 8 of Set 4 | bar harbor
# Processing Record 9 of Set 4 | itarema
# Processing Record 10 of Set 4 | kahului
# Processing Record 11 of Set 4 | rawlins
# Processing Record 12 of Set 4 | morehead
# Processing Record 13 of Set 4 | mehamn
# Processing Record 14 of Set 4 | danville
# Processing Record 15 of Set 4 | winneba
# Processing Record 16 of Set 4 | vagay
# Processing Record 17 of Set 4 | port alberni
# Processing Record 18 of Set 4 | zonguldak
# Processing Record 19 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 20 of Set 4 | malmo
# Processing Record 21 of Set 4 | maarianhamina
# Processing Record 22 of Set 4 | bac lieu
# Processing Record 23 of Set 4 | ambunti
# Processing Record 24 of Set 4 | khorinsk
# Processing Record 25 of Set 4 | gizo
# Processing Record 26 of Set 4 | astolfo dutra
# Processing Record 27 of Set 4 | faanui
# Processing Record 28 of Set 4 | shetpe
# Processing Record 29 of Set 4 | jumla
# Processing Record 30 of Set 4 | sigmaringen
# Processing Record 31 of Set 4 | shitanjing
# Processing Record 32 of Set 4 | itoman
# Processing Record 33 of Set 4 | khatanga
# Processing Record 34 of Set 4 | umm lajj
# Processing Record 35 of Set 4 | gornyye klyuchi
# Processing Record 36 of Set 4 | guanica
# Processing Record 37 of Set 4 | palimbang
# Processing Record 38 of Set 4 | catacaos
# Processing Record 39 of Set 4 | vuktyl
# Processing Record 40 of Set 4 | vagur
# Processing Record 41 of Set 4 | casper
# Processing Record 42 of Set 4 | jackson
# Processing Record 43 of Set 4 | santo anastacio
# Processing Record 44 of Set 4 | marrakesh
# Processing Record 45 of Set 4 | shingu
# Processing Record 46 of Set 4 | juelsminde
# Processing Record 47 of Set 4 | victoria
# Processing Record 48 of Set 4 | ybytimi
# City not found. Skipping...
# Processing Record 49 of Set 4 | severo-kurilsk
# Processing Record 50 of Set 4 | tandil
# Processing Record 1 of Set 5 | mundo nuevo
# Processing Record 2 of Set 5 | shenjiamen
# Processing Record 3 of Set 5 | khash
# Processing Record 4 of Set 5 | upernavik
# Processing Record 5 of Set 5 | goderich
# Processing Record 6 of Set 5 | jiaojiang
# Processing Record 7 of Set 5 | bullas
# Processing Record 8 of Set 5 | namibe
# Processing Record 9 of Set 5 | usogorsk
# Processing Record 10 of Set 5 | codrington
# Processing Record 11 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 5 | kassala
# Processing Record 13 of Set 5 | beloha
# Processing Record 14 of Set 5 | huarmey
# Processing Record 15 of Set 5 | sola
# Processing Record 16 of Set 5 | katsuura
# Processing Record 17 of Set 5 | odweyne
# Processing Record 18 of Set 5 | kontagora
# Processing Record 19 of Set 5 | arraial do cabo
# Processing Record 20 of Set 5 | bubaque
# Processing Record 21 of Set 5 | praia
# Processing Record 22 of Set 5 | cortez
# Processing Record 23 of Set 5 | klaksvik
# Processing Record 24 of Set 5 | naze
# Processing Record 25 of Set 5 | jinchang
# Processing Record 26 of Set 5 | carlisle
# Processing Record 27 of Set 5 | klyuchi
# Processing Record 28 of Set 5 | manati
# Processing Record 29 of Set 5 | chaihe
# Processing Record 30 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 5 | karachev
# Processing Record 32 of Set 5 | yar-sale
# Processing Record 33 of Set 5 | bethel
# Processing Record 34 of Set 5 | mazatlan
# Processing Record 35 of Set 5 | ahipara
# Processing Record 36 of Set 5 | coihaique
# Processing Record 37 of Set 5 | arlit
# Processing Record 38 of Set 5 | monrovia
# Processing Record 39 of Set 5 | longyearbyen
# Processing Record 40 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 5 | olinda
# Processing Record 43 of Set 5 | podporozhye
# Processing Record 44 of Set 5 | honiara
# Processing Record 45 of Set 5 | butaritari
# Processing Record 46 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 5 | harper
# Processing Record 48 of Set 5 | nampula
# Processing Record 49 of Set 5 | saint-francois
# Processing Record 50 of Set 5 | broome
# Processing Record 1 of Set 6 | santiago del estero
# Processing Record 2 of Set 6 | presidencia roque saenz pena
# Processing Record 3 of Set 6 | norfolk
# Processing Record 4 of Set 6 | poum
# Processing Record 5 of Set 6 | skjervoy
# Processing Record 6 of Set 6 | kaili
# Processing Record 7 of Set 6 | malayal
# Processing Record 8 of Set 6 | cherskiy
# Processing Record 9 of Set 6 | inhambane
# Processing Record 10 of Set 6 | bathsheba
# Processing Record 11 of Set 6 | putina
# Processing Record 12 of Set 6 | villacarrillo
# Processing Record 13 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 14 of Set 6 | launceston
# Processing Record 15 of Set 6 | genhe
# Processing Record 16 of Set 6 | breves
# Processing Record 17 of Set 6 | menongue
# Processing Record 18 of Set 6 | luderitz
# Processing Record 19 of Set 6 | coruripe
# Processing Record 20 of Set 6 | nipawin
# Processing Record 21 of Set 6 | san luis de palenque
# Processing Record 22 of Set 6 | kulhudhuffushi
# Processing Record 23 of Set 6 | rio branco
# Processing Record 24 of Set 6 | carnarvon
# Processing Record 25 of Set 6 | dandong
# Processing Record 26 of Set 6 | taksimo
# Processing Record 27 of Set 6 | saint-joseph
# Processing Record 28 of Set 6 | baijiantan
# Processing Record 29 of Set 6 | kholmogory
# Processing Record 30 of Set 6 | kavieng
# Processing Record 31 of Set 6 | trudobelikovskiy
# Processing Record 32 of Set 6 | antalaha
# Processing Record 33 of Set 6 | idrinskoye
# Processing Record 34 of Set 6 | zaranj
# Processing Record 35 of Set 6 | kyren
# Processing Record 36 of Set 6 | uige
# Processing Record 37 of Set 6 | srandakan
# Processing Record 38 of Set 6 | geraldton
# Processing Record 39 of Set 6 | bitung
# Processing Record 40 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 41 of Set 6 | husavik
# Processing Record 42 of Set 6 | flagstaff
# Processing Record 43 of Set 6 | haines junction
# Processing Record 44 of Set 6 | sahrak
# City not found. Skipping...
# Processing Record 45 of Set 6 | tanout
# Processing Record 46 of Set 6 | hofn
# Processing Record 47 of Set 6 | pouebo
# Processing Record 48 of Set 6 | gamba
# Processing Record 49 of Set 6 | lingao
# Processing Record 50 of Set 6 | walvis bay
# Processing Record 1 of Set 7 | lavrentiya
# Processing Record 2 of Set 7 | havelock
# Processing Record 3 of Set 7 | camana
# Processing Record 4 of Set 7 | uvalde
# Processing Record 5 of Set 7 | hasaki
# Processing Record 6 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 7 | hauterive
# Processing Record 8 of Set 7 | lompoc
# Processing Record 9 of Set 7 | kudahuvadhoo
# Processing Record 10 of Set 7 | ayr
# Processing Record 11 of Set 7 | jabiru
# City not found. Skipping...
# Processing Record 12 of Set 7 | saint-marc-des-carrieres
# Processing Record 13 of Set 7 | lasa
# Processing Record 14 of Set 7 | zabol
# Processing Record 15 of Set 7 | luganville
# Processing Record 16 of Set 7 | constitucion
# Processing Record 17 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 18 of Set 7 | bereda
# Processing Record 19 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 20 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 7 | najran
# Processing Record 22 of Set 7 | ibra
# Processing Record 23 of Set 7 | pucallpa
# Processing Record 24 of Set 7 | manokwari
# Processing Record 25 of Set 7 | alofi
# Processing Record 26 of Set 7 | athabasca
# Processing Record 27 of Set 7 | homa bay
# Processing Record 28 of Set 7 | vanimo
# Processing Record 29 of Set 7 | kharp
# Processing Record 30 of Set 7 | bafq
# Processing Record 31 of Set 7 | abomey
# Processing Record 32 of Set 7 | vysokogornyy
# Processing Record 33 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 7 | parkes
# Processing Record 35 of Set 7 | santa cruz
# Processing Record 36 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 37 of Set 7 | kuryk
# Processing Record 38 of Set 7 | hamada
# Processing Record 39 of Set 7 | tomari
# Processing Record 40 of Set 7 | santa margherita ligure
# Processing Record 41 of Set 7 | nishihara
# Processing Record 42 of Set 7 | lagoa
# Processing Record 43 of Set 7 | mayo
# Processing Record 44 of Set 7 | mosetse
# Processing Record 45 of Set 7 | bakonyszentlaszlo
# Processing Record 46 of Set 7 | tokur
# Processing Record 47 of Set 7 | laguna
# Processing Record 48 of Set 7 | skibbereen
# Processing Record 49 of Set 7 | tortoli
# Processing Record 50 of Set 7 | galiwinku
# City not found. Skipping...
# Processing Record 1 of Set 8 | saldanha
# Processing Record 2 of Set 8 | betanzos
# Processing Record 3 of Set 8 | porto torres
# Processing Record 4 of Set 8 | gat
# Processing Record 5 of Set 8 | goroka
# Processing Record 6 of Set 8 | segarcea
# Processing Record 7 of Set 8 | korla
# Processing Record 8 of Set 8 | alihe
# Processing Record 9 of Set 8 | homer
# Processing Record 10 of Set 8 | kaeo
# Processing Record 11 of Set 8 | hamilton
# Processing Record 12 of Set 8 | awbari
# Processing Record 13 of Set 8 | rawson
# Processing Record 14 of Set 8 | vardo
# Processing Record 15 of Set 8 | takaka
# Processing Record 16 of Set 8 | santa maria
# Processing Record 17 of Set 8 | birakan
# Processing Record 18 of Set 8 | biak
# Processing Record 19 of Set 8 | cascais
# Processing Record 20 of Set 8 | poya
# Processing Record 21 of Set 8 | soledade
# Processing Record 22 of Set 8 | aleksandriya
# Processing Record 23 of Set 8 | sabang
# Processing Record 24 of Set 8 | drochia
# Processing Record 25 of Set 8 | fort nelson
# Processing Record 26 of Set 8 | policoro
# Processing Record 27 of Set 8 | henties bay
# Processing Record 28 of Set 8 | ibirama
# Processing Record 29 of Set 8 | kibiti
# Processing Record 30 of Set 8 | narsaq
# Processing Record 31 of Set 8 | altay
# Processing Record 32 of Set 8 | nantucket
# Processing Record 33 of Set 8 | tiarei
# Processing Record 34 of Set 8 | robertsport
# Processing Record 35 of Set 8 | senneterre
# Processing Record 36 of Set 8 | sidi ali
# Processing Record 37 of Set 8 | amlame
# Processing Record 38 of Set 8 | srednekolymsk
# Processing Record 39 of Set 8 | chernyshevskiy
# Processing Record 40 of Set 8 | ballina
# Processing Record 41 of Set 8 | buala
# Processing Record 42 of Set 8 | chumikan
# Processing Record 43 of Set 8 | cam pha
# City not found. Skipping...
# Processing Record 44 of Set 8 | erzin
# Processing Record 45 of Set 8 | hauge
# Processing Record 46 of Set 8 | labrea
# Processing Record 47 of Set 8 | singaraja
# Processing Record 48 of Set 8 | shimanovsk
# Processing Record 49 of Set 8 | port macquarie
# Processing Record 50 of Set 8 | souillac
# Processing Record 1 of Set 9 | zhaoyuan
# Processing Record 2 of Set 9 | nelson bay
# Processing Record 3 of Set 9 | georgetown
# Processing Record 4 of Set 9 | serenje
# Processing Record 5 of Set 9 | porangatu
# Processing Record 6 of Set 9 | tuatapere
# Processing Record 7 of Set 9 | eureka
# Processing Record 8 of Set 9 | port elizabeth
# Processing Record 9 of Set 9 | wuwei
# Processing Record 10 of Set 9 | dolny kubin
# Processing Record 11 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 9 | aksu
# Processing Record 13 of Set 9 | cabo san lucas
# Processing Record 14 of Set 9 | touros
# Processing Record 15 of Set 9 | amahai
# Processing Record 16 of Set 9 | coahuayana
# Processing Record 17 of Set 9 | vitim
# Processing Record 18 of Set 9 | san policarpo
# Processing Record 19 of Set 9 | kamenka
# Processing Record 20 of Set 9 | araouane
# Processing Record 21 of Set 9 | trimbak
# Processing Record 22 of Set 9 | roald
# Processing Record 23 of Set 9 | tahta
# Processing Record 24 of Set 9 | port-gentil
# Processing Record 25 of Set 9 | pangody
# Processing Record 26 of Set 9 | paramonga
# Processing Record 27 of Set 9 | svetlyy
# Processing Record 28 of Set 9 | teul
# City not found. Skipping...
# Processing Record 29 of Set 9 | altea
# Processing Record 30 of Set 9 | shelburne
# Processing Record 31 of Set 9 | cayenne
# Processing Record 32 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 33 of Set 9 | chapais
# Processing Record 34 of Set 9 | princeton
# Processing Record 35 of Set 9 | sakakah
# Processing Record 36 of Set 9 | harrismith
# Processing Record 37 of Set 9 | mombaca
# Processing Record 38 of Set 9 | kaputa
# Processing Record 39 of Set 9 | corinto
# Processing Record 40 of Set 9 | martaban
# Processing Record 41 of Set 9 | la ronge
# Processing Record 42 of Set 9 | bumba
# Processing Record 43 of Set 9 | matagami
# Processing Record 44 of Set 9 | ponta do sol
# Processing Record 45 of Set 9 | kemijarvi
# Processing Record 46 of Set 9 | bulgan
# Processing Record 47 of Set 9 | pinsk
# Processing Record 48 of Set 9 | flinders
# Processing Record 49 of Set 9 | salalah
# Processing Record 50 of Set 9 | komsomolskiy
# Processing Record 1 of Set 10 | kiruna
# Processing Record 2 of Set 10 | kungurtug
# Processing Record 3 of Set 10 | san isidro
# Processing Record 4 of Set 10 | uroteppa
# City not found. Skipping...
# Processing Record 5 of Set 10 | deputatskiy
# Processing Record 6 of Set 10 | zamora
# Processing Record 7 of Set 10 | mglin
# Processing Record 8 of Set 10 | abashiri
# Processing Record 9 of Set 10 | iqaluit
# Processing Record 10 of Set 10 | vao
# Processing Record 11 of Set 10 | vlore
# Processing Record 12 of Set 10 | neringa
# Processing Record 13 of Set 10 | nanortalik
# Processing Record 14 of Set 10 | acapulco
# Processing Record 15 of Set 10 | anadyr
# Processing Record 16 of Set 10 | imeni zhelyabova
# Processing Record 17 of Set 10 | saint-augustin
# Processing Record 18 of Set 10 | camacha
# Processing Record 19 of Set 10 | tigil
# Processing Record 20 of Set 10 | butterworth
# Processing Record 21 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 22 of Set 10 | toora-khem
# Processing Record 23 of Set 10 | forestville
# Processing Record 24 of Set 10 | axim
# Processing Record 25 of Set 10 | plouzane
# Processing Record 26 of Set 10 | cockburn town
# Processing Record 27 of Set 10 | oromocto
# Processing Record 28 of Set 10 | antsohihy
# Processing Record 29 of Set 10 | taoudenni
# Processing Record 30 of Set 10 | seymchan
# Processing Record 31 of Set 10 | emerald
# Processing Record 32 of Set 10 | tura
# Processing Record 33 of Set 10 | ambovombe
# Processing Record 34 of Set 10 | deh rawud
# City not found. Skipping...
# Processing Record 35 of Set 10 | tema
# Processing Record 36 of Set 10 | greece
# Processing Record 37 of Set 10 | kodinar
# Processing Record 38 of Set 10 | lucapa
# Processing Record 39 of Set 10 | airai
# Processing Record 40 of Set 10 | saint anthony
# Processing Record 41 of Set 10 | tefe
# Processing Record 42 of Set 10 | rudnogorsk
# Processing Record 43 of Set 10 | kawalu
# Processing Record 44 of Set 10 | banmo
# City not found. Skipping...
# Processing Record 45 of Set 10 | xining
# Processing Record 46 of Set 10 | chapleau
# Processing Record 47 of Set 10 | rosetta
# Processing Record 48 of Set 10 | cabedelo
# Processing Record 49 of Set 10 | yenagoa
# Processing Record 50 of Set 10 | bud
# Processing Record 1 of Set 11 | sur
# Processing Record 2 of Set 11 | sao lourenco do sul
# Processing Record 3 of Set 11 | hualmay
# Processing Record 4 of Set 11 | waseca
# Processing Record 5 of Set 11 | sinjar
# Processing Record 6 of Set 11 | iracoubo
# Processing Record 7 of Set 11 | chikwawa
# Processing Record 8 of Set 11 | port hardy
# Processing Record 9 of Set 11 | pangnirtung
# Processing Record 10 of Set 11 | portland
# Processing Record 11 of Set 11 | tessalit
# Processing Record 12 of Set 11 | olafsvik
# Processing Record 13 of Set 11 | ituni
# City not found. Skipping...
# Processing Record 14 of Set 11 | sarahan
# Processing Record 15 of Set 11 | kitimat
# Processing Record 16 of Set 11 | ambilobe
# Processing Record 17 of Set 11 | colborne
# Processing Record 18 of Set 11 | knysna
# Processing Record 19 of Set 11 | pangoa
# Processing Record 20 of Set 11 | tihemetsa
# Processing Record 21 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 23 of Set 11 | almaznyy
# Processing Record 24 of Set 11 | siderno
# Processing Record 25 of Set 11 | trapani
# Processing Record 26 of Set 11 | preobrazheniye
# Processing Record 27 of Set 11 | benguela
# Processing Record 28 of Set 11 | ulaanbaatar
# Processing Record 29 of Set 11 | karratha
# Processing Record 30 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 31 of Set 11 | ximei
# Processing Record 32 of Set 11 | havoysund
# Processing Record 33 of Set 11 | nalgonda
# Processing Record 34 of Set 11 | hovd
# Processing Record 35 of Set 11 | burns lake
# Processing Record 36 of Set 11 | kenai
# Processing Record 37 of Set 11 | xuanhua
# Processing Record 38 of Set 11 | simao
# Processing Record 39 of Set 11 | dalvik
# Processing Record 40 of Set 11 | mobaye
# Processing Record 41 of Set 11 | latur
# Processing Record 42 of Set 11 | hervey bay
# Processing Record 43 of Set 11 | fortuna
# Processing Record 44 of Set 11 | kolobrzeg
# Processing Record 45 of Set 11 | mazamari
# Processing Record 46 of Set 11 | guacimo
# Processing Record 47 of Set 11 | novyy urgal
# Processing Record 48 of Set 11 | padang
# Processing Record 49 of Set 11 | luanda
# Processing Record 50 of Set 11 | olovyannaya
# Processing Record 1 of Set 12 | tautira
# Processing Record 2 of Set 12 | vredendal
# Processing Record 3 of Set 12 | kavaratti
# Processing Record 4 of Set 12 | batavia
# Processing Record 5 of Set 12 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 6 of Set 12 | saint-ambroise
# Processing Record 7 of Set 12 | savonlinna
# Processing Record 8 of Set 12 | maceio
# Processing Record 9 of Set 12 | ca mau
# Processing Record 10 of Set 12 | taywarah
# Processing Record 11 of Set 12 | svetlogorsk
# Processing Record 12 of Set 12 | kaniama
# Processing Record 13 of Set 12 | sabzevar
# Processing Record 14 of Set 12 | macclesfield
# Processing Record 15 of Set 12 | semnan
# Processing Record 16 of Set 12 | batagay
# Processing Record 17 of Set 12 | tunduru
# City not found. Skipping...
# Processing Record 18 of Set 12 | esperance
# Processing Record 19 of Set 12 | batagay-alyta
# Processing Record 20 of Set 12 | leningradskiy
# Processing Record 21 of Set 12 | darhan
# Processing Record 22 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 23 of Set 12 | cape elizabeth
# City not found. Skipping...
# Processing Record 24 of Set 12 | trairi
# Processing Record 25 of Set 12 | vila velha
# Processing Record 26 of Set 12 | marathon
# Processing Record 27 of Set 12 | belaya gora
# Processing Record 28 of Set 12 | kouango
# Processing Record 29 of Set 12 | megion
# Processing Record 30 of Set 12 | ilebo
# Processing Record 31 of Set 12 | san juan
# Processing Record 32 of Set 12 | oga
# Processing Record 33 of Set 12 | mbulu
# Processing Record 34 of Set 12 | salinopolis
# Processing Record 35 of Set 12 | kasongo-lunda
# Processing Record 36 of Set 12 | collierville
# Processing Record 37 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 38 of Set 12 | leh
# Processing Record 39 of Set 12 | gornoye loo
# Processing Record 40 of Set 12 | dharchula
# Processing Record 41 of Set 12 | filadelfia
# Processing Record 42 of Set 12 | lodja
# Processing Record 43 of Set 12 | ostrovnoy
# Processing Record 44 of Set 12 | saint-leu
# Processing Record 45 of Set 12 | medea
# Processing Record 46 of Set 12 | coihueco
# Processing Record 47 of Set 12 | houma
# Processing Record 48 of Set 12 | richards bay
# Processing Record 49 of Set 12 | kieta
# Processing Record 50 of Set 12 | izumo
# Processing Record 1 of Set 13 | staunton
# Processing Record 2 of Set 13 | kushmurun
# Processing Record 3 of Set 13 | kodinsk
# Processing Record 4 of Set 13 | sao francisco de paula
# Processing Record 5 of Set 13 | aykhal
# Processing Record 6 of Set 13 | kutum
# Processing Record 7 of Set 13 | catamarca
# Processing Record 8 of Set 13 | talnakh
# Processing Record 9 of Set 13 | dibaya
# City not found. Skipping...
# Processing Record 10 of Set 13 | northam
# Processing Record 11 of Set 13 | kalanaur
# Processing Record 12 of Set 13 | tevaitoa
# Processing Record 13 of Set 13 | kabinda
# Processing Record 14 of Set 13 | marawi
# Processing Record 15 of Set 13 | kampot
# Processing Record 16 of Set 13 | absam
# Processing Record 17 of Set 13 | siverek
# Processing Record 18 of Set 13 | barsovo
# Processing Record 19 of Set 13 | kenora
# Processing Record 20 of Set 13 | north bend
# Processing Record 21 of Set 13 | vila
# Processing Record 22 of Set 13 | balfour
# Processing Record 23 of Set 13 | ayorou
# Processing Record 24 of Set 13 | tyrma
# Processing Record 25 of Set 13 | pietersburg
# Processing Record 26 of Set 13 | santa catarina de tepehuanes
# Processing Record 27 of Set 13 | mount darwin
# Processing Record 28 of Set 13 | ust-tsilma
# Processing Record 29 of Set 13 | marzuq
# Processing Record 30 of Set 13 | karagay
# Processing Record 31 of Set 13 | catuday
# Processing Record 32 of Set 13 | alekseyevsk
# Processing Record 33 of Set 13 | panaba
# Processing Record 34 of Set 13 | strezhevoy
# Processing Record 35 of Set 13 | hami
# Processing Record 36 of Set 13 | ponta delgada
# Processing Record 37 of Set 13 | cuamba
# Processing Record 38 of Set 13 | edd
# Processing Record 39 of Set 13 | sorland
# Processing Record 40 of Set 13 | dicabisagan
# Processing Record 41 of Set 13 | ondorhaan
# City not found. Skipping...
# Processing Record 42 of Set 13 | umea
# Processing Record 43 of Set 13 | gympie
# Processing Record 44 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 45 of Set 13 | novoseleznevo
# Processing Record 46 of Set 13 | hobyo
# Processing Record 47 of Set 13 | te anau
# Processing Record 48 of Set 13 | chancay
# Processing Record 49 of Set 13 | kozhva
# Processing Record 50 of Set 13 | praia da vitoria
# Processing Record 1 of Set 14 | polson
# Processing Record 2 of Set 14 | duz
# City not found. Skipping...
# Processing Record 3 of Set 14 | dzhebariki-khaya
# Processing Record 4 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 5 of Set 14 | taltal
# Processing Record 6 of Set 14 | novyy buyan
# Processing Record 7 of Set 14 | the valley
# Processing Record 8 of Set 14 | beringovskiy
# Processing Record 9 of Set 14 | mirina
# City not found. Skipping...
# Processing Record 10 of Set 14 | mkushi
# Processing Record 11 of Set 14 | olyka
# Processing Record 12 of Set 14 | gotha
# Processing Record 13 of Set 14 | eldikan
# City not found. Skipping...
# Processing Record 14 of Set 14 | baturaja
# Processing Record 15 of Set 14 | shakawe
# Processing Record 16 of Set 14 | la rioja
# Processing Record 17 of Set 14 | itupiranga
# Processing Record 18 of Set 14 | dotnuva
# Processing Record 19 of Set 14 | maues
# Processing Record 20 of Set 14 | san patricio
# Processing Record 21 of Set 14 | quballat
# Processing Record 22 of Set 14 | eskil
# Processing Record 23 of Set 14 | berlevag
# Processing Record 24 of Set 14 | temir
# Processing Record 25 of Set 14 | barkly west
# Processing Record 26 of Set 14 | mendoza
# Processing Record 27 of Set 14 | redmond
# Processing Record 28 of Set 14 | la gaulette
# City not found. Skipping...
# Processing Record 29 of Set 14 | qandala
# Processing Record 30 of Set 14 | bahia honda
# Processing Record 31 of Set 14 | bilma
# Processing Record 32 of Set 14 | lucatan
# City not found. Skipping...
# Processing Record 33 of Set 14 | les cayes
# Processing Record 34 of Set 14 | okhotsk
# Processing Record 35 of Set 14 | ndende
# Processing Record 36 of Set 14 | aguimes
# Processing Record 37 of Set 14 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 38 of Set 14 | guarapari
# Processing Record 39 of Set 14 | straumen
# Processing Record 40 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 14 | champerico
# Processing Record 42 of Set 14 | okha
# Processing Record 43 of Set 14 | santa barbara
# Processing Record 44 of Set 14 | galesong
# Processing Record 45 of Set 14 | shambu
# Processing Record 46 of Set 14 | pleasanton
# Processing Record 47 of Set 14 | kumluca
# Processing Record 48 of Set 14 | labuhan
# Processing Record 49 of Set 14 | phnum penh
# City not found. Skipping...
# Processing Record 50 of Set 14 | khor
# Processing Record 1 of Set 15 | unai
# Processing Record 2 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 3 of Set 15 | druzhba
# Processing Record 4 of Set 15 | mantes-la-ville
# Processing Record 5 of Set 15 | galgani
# City not found. Skipping...
# Processing Record 6 of Set 15 | afgoye
# City not found. Skipping...
# Processing Record 7 of Set 15 | santa rosa
# Processing Record 8 of Set 15 | mapiri
# Processing Record 9 of Set 15 | melfort
# Processing Record 10 of Set 15 | lima
# Processing Record 11 of Set 15 | kurilsk
# Processing Record 12 of Set 15 | tukrah
# Processing Record 13 of Set 15 | tezu
# Processing Record 14 of Set 15 | ginir
# Processing Record 15 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 16 of Set 15 | nikki
# Processing Record 17 of Set 15 | college
# Processing Record 18 of Set 15 | tateyama
# Processing Record 19 of Set 15 | synya
# Processing Record 20 of Set 15 | tulagi
# Processing Record 21 of Set 15 | lappersdorf
# Processing Record 22 of Set 15 | goundam
# Processing Record 23 of Set 15 | minas
# Processing Record 24 of Set 15 | longmont
# Processing Record 25 of Set 15 | caravelas
# Processing Record 26 of Set 15 | moree
# Processing Record 27 of Set 15 | muswellbrook
# Processing Record 28 of Set 15 | paita
# Processing Record 29 of Set 15 | saint-georges
# Processing Record 30 of Set 15 | almas
# Processing Record 31 of Set 15 | pyu
# Processing Record 32 of Set 15 | kampong thum
# Processing Record 33 of Set 15 | ojuelos de jalisco
# Processing Record 34 of Set 15 | sao joao da barra
# Processing Record 35 of Set 15 | severobaykalsk
# Processing Record 36 of Set 15 | rabo de peixe
# Processing Record 37 of Set 15 | ribeirao branco
# Processing Record 38 of Set 15 | buluang
# Processing Record 39 of Set 15 | hashtrud
# Processing Record 40 of Set 15 | santiago
# Processing Record 41 of Set 15 | myitkyina
# Processing Record 42 of Set 15 | denpasar
# Processing Record 43 of Set 15 | konokovo
# Processing Record 44 of Set 15 | manado
# Processing Record 45 of Set 15 | aswan
# Processing Record 46 of Set 15 | kuldiga
# Processing Record 47 of Set 15 | maniitsoq
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City      Lat       Lng Current Description  Max Temp  \
# 0            Omboue  -1.5746    9.2618          light rain     81.19
# 1          Zhigansk  66.7697  123.3711           clear sky     -8.32
# 2  Hodmezovasarhely  46.4167   20.3333           clear sky     72.18
# 3      Punta Arenas -53.1500  -70.9167           clear sky     42.91
# 4            Albany  42.6001  -73.9662     overcast clouds     48.94
# 5            Bonfim   3.0833  -59.9500     overcast clouds     86.36
# 6      Puerto Ayora  -0.7393  -90.3518    scattered clouds     78.76
# 7     Marsh Harbour  26.5412  -77.0636    scattered clouds     78.64
# 8         Busselton -33.6500  115.3333     overcast clouds     61.75
# 9      Quatre Cocos -20.2078   57.7625     overcast clouds     80.10
#
#    Humidity  Cloudiness  Wind Speed Country
# 0        82         100        7.11      GA
# 1        99           9        8.12      RU
# 2        39           7       12.01      HU
# 3        56           0       16.11      CL
# 4        70         100        1.99      US
# 5        47          98        7.11      BR
# 6        81          48        7.09      EC
# 7        80          40       17.49      BS
# 8        73         100        6.15      AU
# 9        77         100       13.44      MU

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Omboue      GA  -1.5746    9.2618     81.19        82
# 1          Zhigansk      RU  66.7697  123.3711     -8.32        99
# 2  Hodmezovasarhely      HU  46.4167   20.3333     72.18        39
# 3      Punta Arenas      CL -53.1500  -70.9167     42.91        56
# 4            Albany      US  42.6001  -73.9662     48.94        70
# 5            Bonfim      BR   3.0833  -59.9500     86.36        47
# 6      Puerto Ayora      EC  -0.7393  -90.3518     78.76        81
# 7     Marsh Harbour      BS  26.5412  -77.0636     78.64        80
# 8         Busselton      AU -33.6500  115.3333     61.75        73
# 9      Quatre Cocos      MU -20.2078   57.7625     80.10        77
#
#    Cloudiness  Wind Speed Current Description
# 0         100        7.11          light rain
# 1           9        8.12           clear sky
# 2           7       12.01           clear sky
# 3           0       16.11           clear sky
# 4         100        1.99     overcast clouds
# 5          98        7.11     overcast clouds
# 6          48        7.09    scattered clouds
# 7          40       17.49    scattered clouds
# 8         100        6.15     overcast clouds
# 9         100       13.44     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
